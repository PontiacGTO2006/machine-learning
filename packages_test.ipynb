# %% [markdown]
# # Test Python and Jupyter Notebook
# To run each cell, click inside it and then use the **Run** button or use **Ctl+Enter** to run the cell.
# Update 2/6/2026: **Python 3.12.2** is the latest stable and supported version for this repository. All required packages below have been installed and tested.

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print(tf.__file__)
# Out:
# TensorFlow version: 2.20.0
# c:\Users\car-m\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py

# %%
import keras

print(keras.__version__)
# Out:
# 3.11.3

# %%
import numpy as np
import matplotlib
import pandas

print(np.__version__)
print(matplotlib.__version__)
print(pandas.__version__)
# Out:
# 2.2.6
# 3.10.8
# 2.3.0

# %%
import requests
import bs4

print(requests.__version__)
print(bs4.__version__)
# Out:
# 2.32.3
# 4.12.3

# %%
import nltk
import sklearn # this is now officially 'scikit-learn' due to deprecations
import joblib

print(nltk.__version__)
print(sklearn.__version__)
print(joblib.__version__)
# Out:
# 3.9.4
# 1.7.2
# 1.5.2

# %% [markdown]
# # Installing Python Libraries

# %% [markdown]
# For any of these libraries that are not installed, you can use the cell below to import them. The command will be `!pip install <library_name>` i.e. `!pip install numpy`

# %%
# Run the cell to install the following libraries
# !pip install numpy
# !pip install matplotlib
# !pip install pandas
# !pip install tensorflow
# !pip install keras
# !pip install beautifulsoup4
# !pip install requests
# !pip install joblib
# !pip install nltk
# !pip install scikit-learn
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# ...
