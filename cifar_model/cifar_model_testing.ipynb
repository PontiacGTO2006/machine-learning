# %% [markdown]
# # CIFAR Convolutional Neural Network Model Testing
#
# This Jupyter Notebook contains code to test the CIFAR CNN model (in the CIFAR_model.ipynb notebook) on real-world images. For reference, this Convolutional Neural Network Model (CNN) predicts what an image represents based on an input. For example, if given an image of a frog, it will output a prediction of a 'frog'. It works for things such as airplanes, automobiles, birds, cats, deer, etc.
#
# Use this notebook to run the new cifar data network. Remember, you can add
# ```model.save('cifar_model.h5')```
# to save and export your model.
#
# The model was trained on data from the CIFAR dataset of 50,000 images of everyday objects. There are several test images in the folder "test_images" in this directory. **Change the image path in the "path" variable near the bottom of the next code cell to feed various images to the model**. Feel free to upload your own to the folder if you have cloned this repo locally.
#
# To look under the hood of the CIFAR model, go to the ```CIFAR_model.ipynb``` file.

# %%
from keras.preprocessing import image
from PIL import Image,ImageChops 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import backend as K
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Load in the original data
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
(train_images_backup, train_labels_backup), (test_images_backup, test_labels_backup) = cifar10.load_data() 

print("CIFAR10 data loaded")

label_names=['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'] 
train_labels_backup = [item for sublist in train_labels_backup for item in sublist]
test_labels_backup = [item for sublist in test_labels_backup for item in sublist]

# This will work for the models if you download them from the links above. 
# If you want to export your own models, use the name of them here instead. 
model_1 = tf.keras.models.load_model('cifar_model_v2.h5')
#model_1.compile(loss=keras.losses.categorical_crossentropy, optimizer='adam', metrics=['accuracy'])
# model_2 = tf.keras.models.load_model('cnn_model.h5') - you can also test the handwriting recognition cnn model here

def plot_image(array, i, labels):
  plt.imshow(np.squeeze(array[i]))
  plt.title(" This is " + label_names[labels[i]])
  plt.xticks([])
  plt.yticks([])
  plt.show()

def predict_image(model, x):
  x = x.astype('float32')
  x = x / 255.0

  x = np.expand_dims(x, axis=0)

  image_predict = model.predict(x, verbose=0)
  print("Predicted Label: ", label_names[np.argmax(image_predict)])

  plt.imshow(np.squeeze(x))
  plt.xticks([])
  plt.yticks([])
  plt.show()
 
  # uncomment this line if you want to see the array of predictions
  # print(image_predict)
  return image_predict


def plot_value_array(predictions_array, true_label, h):
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array[0], color="#777777")
  plt.ylim([(-1*h), h])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')
  plt.show()


# Code to load an image through the model
# To use a different image upload it and change the name here.
path = "test_images/bird-test.jpg"
img = image.load_img(path, target_size=(32,32), color_mode = "rgb")
x = image.img_to_array(img)
true_label = 6

# Predicting the label using model_1.
p_arr = predict_image(model_1, x)
# This will plot the values on a graph. The last argument is the height of the y-axis.
plot_value_array(p_arr, 3, 1) # currently not working

# Displaying the 100th image from the original dataset
plot_image(test_images, 100, test_labels_backup)

# Predicting the label using model_1 on an image from test_images
img_loc = 100
img = test_images[img_loc]
x = image.img_to_array(img)
p_arr = predict_image(model_1, x)
true_label = test_labels_backup[img_loc]
print(true_label)
plot_value_array(p_arr, true_label, 1)

# Create an array of random numbers from 0 to 255 of size (32, 32, 3)
x = np.random.randint(0, 255, (32, 32, 3) )
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# CIFAR10 data loaded
# Predicted Label:  bird
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 78
#      76 p_arr = predict_image(model_1, x)
#      77 # This will plot the values on a graph. The last argument is the height of the y-axis.
# ---> 78 plot_value_array(p_arr, 3, 3)
#      80 # Displaying the 100th image from the original dataset
#      81 plot_image(test_images, 100, test_labels_backup)
#
# Cell In[9], line 59, in plot_value_array(predictions_array, true_label, h)
#      57 plt.xticks(range(10))
#      58 plt.yticks([])
# ---> 59 thisplot = plt.bar(range(10), predictions_array[0], color="#777777")
#      60 plt.ylim([(-1*h), h])
#      61 predicted_label = np.argmax(predictions_array)
#
# File c:\Users\car-m\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2989, in bar(x, height, width, bottom, align, data, **kwargs)
#    2978 @_copy_docstring_and_deprecators(Axes.bar)
#    2979 def bar(
#    2980     x: float | ArrayLike,
#    (...)
#    2987     **kwargs,
#    2988 ) -> BarContainer:
# -> 2989     return gca().bar(
#    2990         x,
#    2991         height,
#    2992         width=width,
#    2993         bottom=bottom,
#    2994         align=align,
#    2995         **({"data": data} if data is not None else {}),
#    2996         **kwargs,
#    2997     )
#
# File c:\Users\car-m\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\car-m\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:2583, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2580     if yerr is not None:
#    2581         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2583 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2584     # Make args iterable too.
#    2585     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2587 # Now that units have been converted, set the tick locations.
#    2588 if orientation == 'vertical':
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_stride_tricks_impl.py:544, in broadcast_arrays(subok, *args)
#     537 # nditer is not used here to avoid the limit of 32 arrays.
#     538 # Otherwise, something like the following one-liner would suffice:
#     539 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     540 #                  order='C').itviews
#     542 args = [np.array(_m, copy=None, subok=subok) for _m in args]
# --> 544 shape = _broadcast_shape(*args)
#     546 result = [array if array.shape == shape
#     547           else _broadcast_to(array, shape, subok=subok, readonly=False)
#     548                           for array in args]
#     549 return tuple(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\lib\_stride_tricks_impl.py:419, in _broadcast_shape(*args)
#     414 """Returns the shape of the arrays that would result from broadcasting the
#     415 supplied arrays against each other.
#     416 """
#     417 # use the old-iterator because np.nditer does not handle size 0 arrays
#     418 # consistently
# --> 419 b = np.broadcast(*args[:32])
#     420 # unfortunately, it cannot handle 32 or more arguments directly
#     421 for pos in range(32, len(args), 31):
#     422     # ironically, np.broadcast does not properly handle np.broadcast
#     423     # objects (it treats them as scalars)
#     424     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (10,) and arg 1 with shape (1000,).

# %% [markdown]
# # Test 1
#
# Run a square image of a frog, or an airplane or any of the other classes through your network. What is the prediction?

# %%
# Write code for test 1 here

# %% [markdown]
# # Test 2
#
# Run a randomly generated image through the network. See if you can notice any bias with what it predicts.

# %%
# Write code for test 2 here

# %% [markdown]
# # Test 3
#
# Test the network with some random images from the test_images set. See what it does with these.

# %%
# Write code for test 3 here
