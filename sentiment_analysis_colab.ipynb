# %% [markdown]
# <a href="https://colab.research.google.com/github/PontiacGTO2006/machine-learning/blob/main/sentiment_analysis_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment Analysis: Preparing Data (Google Colab Version)
# **IMPORTANT NOTE:** This is a separate version of the Sentiment Analysis model, ran on the Google Colab cloud server. Although I try to export this notebook and commit it back out to the repository as often as psosible, there may be differences between this file and the locally-run **sentiment_analysis.ipynb** file.
#
# So far, you've created a simple system for making a call about whether a review has a positive or negative overall rating. This system works if the review uses words you've pre-determined as positive or negative.
#
# But what about reviews with more complicated words or phrases? To better understand text from the reviews, you'll build a neural network trained using data from reviews. This network will create a more nuanced understanding of the review data.
#
# There are three main stages of creating this network:
#
#
# *   Importing and cleaning up the data
# *   Vectorizing the data
# *   Creating and training the network

# %% [markdown]
# ## Importing Libraries & Tools
# In the code cell below, you'll import all the libraries and tools required for the sentiment analysis project.

# %%
# Import the pandas library.
import pandas as pd
# Import the numpy library.
import numpy as np

# Import the string library.
import string
# Import the punctuation library.
from string import punctuation
# Import the nltk library.
import nltk
# Import the stopwords.
from nltk.corpus import stopwords
# Download the stopwords
nltk.download('stopwords')

# Import the TensorFlow library.
import tensorflow as tf

# Import the Input, Dense, Dropout layers.
from tensorflow import keras # need to import keras for next line to work
from keras.layers import Input, Dense, Dropout
# Import the Sequential model.
from keras import Sequential

# Import the sklearn library.
import sklearn
# Import the train_test_split model selection.
from sklearn.model_selection import train_test_split
# Import the CountVectorizer, TfidfTransformer, TfidfVectorizer.
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer

# Import the joblib library.
import joblib

# Import Pytorch and necessary libraries (currently using for LR experimentation to curb overfitting)
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Preparing the Data
# To get started, you'll first import a dataset of reviews to your project. Next, you'll prepare the data to get the information required to train a network.

# %% [markdown]
# ## Importing the Data
# To import the data, you'll download the "Reviews.csv" file and load it into your project using the **.read_csv** function.

# %%
# Use the .read_csv function to read the "Reviews.csv" data into the notebook.
data = pd.read_csv('Reviews.csv')

# Use data.head() to print out the first few lines of data.
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ## Extracting the Data
# Now that you've imported the data, you'll extract only the parts you need to train the network.

# %%
# Add the 'UserId', 'Id', and 'Time' to the drop function to drop them.
data = data.drop(['UserId', 'Id', 'Time'], axis=1)

# Use dropna() to drop empty rows.
data.dropna(inplace=True)

# Print the first few lines of the data.
data.head()
# Out:
#     ProductId                      ProfileName  HelpfulnessNumerator  \
# 0  B001E4KFG0                       delmartian                     1
# 1  B00813GRG4                           dll pa                     0
# 2  B000LQOCH0  Natalia Corres "Natalia Corres"                     1
# 3  B000UA0QIQ                             Karl                     3
# 4  B006K2ZZ7K    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score                Summary  \
# 0                       1      5  Good Quality Dog Food
# 1                       0      1      Not as Advertised
# 2                       1      4  "Delight" says it all
# 3                       3      2         Cough Medicine
# 4                       0      5            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ## Adding a Polarity Column
# Now, it's time to add a new column labeling the rating as either positive, negative, or neutral. To do this, you'll use the reviewers' star ratings. If the reviewer gave the item more than 3 stars, then it's a positive review. If the reviewer gave the item less than 3 stars, then it's a negative review. Finally, if the reviewer gave the item 3 stars, then it is neutral.

# %%
# Create a new column to keep track of if the review is positive negative or neutral.
data['Polarity_Rating'] = data['Score'].apply(lambda x: 'Positive' if x > 3 else('Neutral' if x==3 else 'Negative'))

# Print the first few lines of the data.
data.head()
# Out:
#     ProductId                      ProfileName  HelpfulnessNumerator  \
# 0  B001E4KFG0                       delmartian                     1
# 1  B00813GRG4                           dll pa                     0
# 2  B000LQOCH0  Natalia Corres "Natalia Corres"                     1
# 3  B000UA0QIQ                             Karl                     3
# 4  B006K2ZZ7K    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score                Summary  \
# 0                       1      5  Good Quality Dog Food
# 1                       0      1      Not as Advertised
# 2                       1      4  "Delight" says it all
# 3                       3      2         Cough Medicine
# 4                       0      5            Great taffy
#
#                                                 Text Polarity_Rating
# 0  I have bought several of the Vitality canned d...        Positive
# 1  Product arrived labeled as Jumbo Salted Peanut...        Negative
# 2  This is a confection that has been around a fe...        Positive
# 3  If you are looking for the secret ingredient i...        Negative
# 4  Great taffy at a great price.  There was a wid...        Positive

# %% [markdown]
# ## Sampling the Data
# Now, it's time to separate the data into groups based on whether it's positive, negative, or neutral. You'll also get a sample of 8,000 reviews from each list to perform tests. 8000 is a good sample size since it won't create a data set that's too large.

# %%
# Separate the positive data into a group.
data_positive = data[data['Polarity_Rating'] == 'Positive']
# Separate the negative data into a group.
data_negative = data[data['Polarity_Rating'] == 'Negative']
# Separate the neutral data into a group.
data_neutral = data[data['Polarity_Rating'] == 'Neutral']

# Print out the shape of each list.
print("Negative: ", data_negative.shape)
print("Neutral: ", data_neutral.shape)
print("Positive: ", data_positive.shape)
# Out:
# Negative:  (82007, 8)
# Neutral:  (42638, 8)
# Positive:  (443756, 8)

# %%
# Get a sample from the positive reviews.
data_positive = data_positive.sample(8000)
# Get a sample from the negative reviews.
data_negative = data_negative.sample(8000)

# Get a sample from the neutral reviews.
data_neutral = data_neutral.sample(8000)

# Print out the shape of the new lists.
print("Negative: ", data_negative.shape)
print("Neutral: ", data_neutral.shape)
print("Positive: ", data_positive.shape)
# Out:
# Negative:  (8000, 8)
# Neutral:  (8000, 8)
# Positive:  (8000, 8)

# %%
# Combine the positive, negative, and neutral data lists together to create one large dataset.
data = pd.concat([data_positive, data_negative, data_neutral])

# Print the data's shape.
print(data.shape)
# Out:
# (24000, 8)

# %% [markdown]
# # Cleaning the Text
# Now that you have one large list of the data, it's time to clean the actual text. You'll create a function that removes punctuation and stopwords from the text.
#
# You'll first remove the stopwords. The string library has a built-in list of stopwords. Stopwords are words that don't contain important information and are common in English. Examples include "is," "our," "the," etc.
#
# Next, you'll remove the punctuation from the text by creating a for loop and adding the text without the punctuation into a list called no_punctuation.
#
# Finally, you'll return the filtered text. To do this, you'll create a for loop that splits the text into a list of filtered words and checks if the lowercase word is in the stopwords. This will ensure that the data is filtered properly.
#
# Once your data is cleaned and prepared, you'll view the new data by creating a new column and recreating the data to work with the information you need.

# %%
# Create a function called text_cleanup that returns the text without the stopwords and punctuation.
def text_cleanup(text):
    get_stopwords = stopwords.words('english')
    no_punctuation = []
    for i in text:
        if i not in string.punctuation:
            no_punctuation.append(i)
    no_punctuation = ''.join(no_punctuation)

    filtered_words = []
    for word in no_punctuation.split():
        if word.lower() not in get_stopwords:
            filtered_words.append(word)
    return ''.join(filtered_words)

# %%
# Create a new column called reviews that cleans up the text.
data['reviews'] = data['Text'].apply(text_cleanup)

# Print the first few lines of the data.
data.head()
# Out:
#          ProductId                ProfileName  HelpfulnessNumerator  \
# 515345  B001EQ5CHK   M. Carter "Aspen Runner"                     0
# 28789   B0002VXZ40                    Emma B.                     0
# 386573  B001E53020  M. Hammond "ColemanFlGuy"                     3
# 203496  B000CQC04Q                  imuneekru                     2
# 163516  B001UJIFRU                         me                     0
#
#         HelpfulnessDenominator  Score  \
# 515345                       0      5
# 28789                        0      4
# 386573                       3      5
# 203496                       2      5
# 163516                       0      5
#
#                                            Summary  \
# 515345                           Great coffee !!!!
# 28789   Not the Best, but the price can't be beat!
# 386573          Sun-Maid California Golden Raisins
# 203496                     Best unsung home remedy
# 163516                                   love it!!
#
#                                                      Text Polarity_Rating  \
# 515345  This is excellent coffee. Bold and rich, it ea...        Positive
# 28789   Wasabi peas are one of my favorite snacks, and...        Positive
# 386573  I really enjoyed eating these raisins and they...        Positive
# 203496  I never liked the flavor of this tea initially...        Positive
# 163516  Vita-CoCo has a few different flavored coconut...        Positive
#
#                                                   reviews
# 515345  excellentcoffeeBoldricheasilysurpassescrowdfav...
# 28789   WasabipeasonefavoritesnacksfindingAmazonallowe...
# 386573  reallyenjoyedeatingraisinsabsolutelydeliciouso...
# 203496  neverlikedflavorteainitiallyboxsittingbackcupb...
# 163516  VitaCoCodifferentflavoredcoconutwatersoneacaip...

# %%
# Add the review data and polarity rating columns to recreate the dataset with just the needed data.
data = data[['reviews', 'Polarity_Rating']]

# Print the first few lines of the data.
data.head()
# Out:
#                                                   reviews Polarity_Rating
# 515345  excellentcoffeeBoldricheasilysurpassescrowdfav...        Positive
# 28789   WasabipeasonefavoritesnacksfindingAmazonallowe...        Positive
# 386573  reallyenjoyedeatingraisinsabsolutelydeliciouso...        Positive
# 203496  neverlikedflavorteainitiallyboxsittingbackcupb...        Positive
# 163516  VitaCoCodifferentflavoredcoconutwatersoneacaip...        Positive

# %% [markdown]
# ## One Hot Encoding
# One-hot encoding is a process of creating data categories that the network can understand and that won't have an inherent bias. In this case, you'll make a matrix of three columns (positive, negative, and neutral) and put either a 1 or 0 in the row for the review text. This way, the network can be trained using the matrix to validate it's guesses.

# %%
# Apply one-hot encoding to your data by using the pandas get_dummies function.
one_hot = pd.get_dummies(data["Polarity_Rating"])

# Print the first few lines of the one-hot data.
one_hot.head()
# Out:
#         Negative  Neutral  Positive
# 515345     False    False      True
# 28789      False    False      True
# 386573     False    False      True
# 203496     False    False      True
# 163516     False    False      True

# %%
# Combine your data and the one_hot data to combine the data into one big dataset.
data = pd.concat([data, one_hot], axis=1)

# Print the first few lines of the data.
data.head()
# Out:
#                                                   reviews Polarity_Rating  \
# 515345  excellentcoffeeBoldricheasilysurpassescrowdfav...        Positive
# 28789   WasabipeasonefavoritesnacksfindingAmazonallowe...        Positive
# 386573  reallyenjoyedeatingraisinsabsolutelydeliciouso...        Positive
# 203496  neverlikedflavorteainitiallyboxsittingbackcupb...        Positive
# 163516  VitaCoCodifferentflavoredcoconutwatersoneacaip...        Positive
#
#         Negative  Neutral  Positive
# 515345     False    False      True
# 28789      False    False      True
# 386573     False    False      True
# 203496     False    False      True
# 163516     False    False      True

# %%
# Drop the 'Polarity_Rating' column.
data.drop(['Polarity_Rating'], axis=1, inplace=True)

# Print the first few lines of the data.
data.head()
# Out:
#                                                   reviews  Negative  Neutral  \
# 515345  excellentcoffeeBoldricheasilysurpassescrowdfav...     False    False
# 28789   WasabipeasonefavoritesnacksfindingAmazonallowe...     False    False
# 386573  reallyenjoyedeatingraisinsabsolutelydeliciouso...     False    False
# 203496  neverlikedflavorteainitiallyboxsittingbackcupb...     False    False
# 163516  VitaCoCodifferentflavoredcoconutwatersoneacaip...     False    False
#
#         Positive
# 515345      True
# 28789       True
# 386573      True
# 203496      True
# 163516      True

# %% [markdown]
# ## Train and Test Split
# Now that you have all the data cleaned up and formatted for the network, you'll split it into train and test sets. To split the data into these groups, you'll use the **sklearn** library. You'll use the built-in **train_test_split()** function to get a train and test data sets.
#
# To feed data into the network, you need an input set and an output set. The input will be the reviews, and the output will be the polarity.

# %%
# Set x_rev equal to the reviews column by adding .values to the end to get the data itself out of the column.
x_rev = data["reviews"].values

# Set y_pol to the data with the reviews column dropped.
y_pol = data.drop("reviews", axis=1)

# Create your train and test datasets.
x_rev_train, x_rev_test, y_pol_train, y_pol_test = train_test_split(x_rev, y_pol, test_size=0.30, shuffle=True, random_state=42)

# %% [markdown]
# # Vectorizing
# So far, you've cleaned up all the text data from the reviews and separated them into input and output sets.
#
# Now that you have only the important words of the reviews data and a matrix to represent their polarity, you'll turn the text into numbers so that the network can understand the format.
#
# You'll do this using a process called **Vectorizing**.
#
# **Vectorizing** converts text data into numerical data so that a neural network can perform calculations with it.
#
# To do this, you're going to use **sklearn**. This library has a lot of built-in libraries for reworking data into its numerical form.
#
# This process has two phases: **fit** and **transform**.
#
# Luckily, the sklearn library has built-in functions to do most of the work for you during this stage. You'll use a vectorizer called **CountVectorizor** that uses the count of each word to do the vectorization process.
#
# You'll follow the steps below to create a vocabulary from the review data and then transform the input datasets into that vocabulary.

# %% [markdown]
# ## Fit and Tokenize Stage
# First, you'll create a vocabulary using the Keras Tokenizer. We'll lemit the max vocab to 10,000 and the max length to 150 to prevent the model from memorizing too much of the vocab. You'll use all the review data from the dataset and create a set of the frequency of each word. Then, the vocabulary will be saved to a variable.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

MAX_VOCAB = 10000
MAX_LEN = 150

# functions the same way as the previous CountVectorizer
tokenizer = Tokenizer(num_words=MAX_VOCAB, oov_token='<OOV>')
tokenizer.fit_on_texts(x_rev)

# Convert reviews to integer sequences
x_seq = tokenizer.texts_to_sequences(x_rev)

# Pad so all sequences are the same length
x_padded = pad_sequences(x_seq, maxlen=MAX_LEN, padding='post', truncating='post')

# Save the vocab to a variable
vocab = tokenizer.word_index
print(vocab)
# Out:
# {'<OOV>': 1, '...': 2, '...': 3, 'boughtproductsmallerpackagingtakeworkenjoytwo10packagesmoldysaidbestmar132013canttrustwontbuy': 4, 'reviewproductsellergreatbrbrheardgoodsleepcouldntfindlocalboughtstunkhousetasteawfulsavemoneybuytea': 5, 'crackersdeliciousbitsweeterhopedstillreallytastycrunchytrywaitgetsalebuyquiteexpensive': 6, '...': 7, 'pricetwiceonebuyproductstoregivesnobodyconsiderproductprices': 8, 'dogseemsallergicpoultrythoughtwouldswitchlambbasedformulausuallygoodeaterdogonesmellstuffwouldntcomebackunderstandwellnessputshigherendingredientsfooddogdoesntlikegoesmoneyrightdrain': 9, 'usedgetjuniperridgejuniperridgewhitesagewildminttealovehintrawhoneywantedgiveteatrydisappointedteatastelessexpected': 10, 'tasteokayblownawayhiddenfacttrulydecaffeinatedcoffeeplacefindbottomboxwantfirstthingmorning': 11, 'useddogspuzzletoywouldeatneverseemedexcitedgottoy': 12, '...': 13, '...': 14, 'enoughflavormurkybrowncolorlackingaromaenjoyvarietieslinepreferdifferentbrandrosehipteaiddrinkregularblackteathough': 15, '...': 16, 'lovetasteherbalteatwicenoticedraspingbreathingdiscomfortmaymaytriggeredbought4boxestryingsamplerimstartingthinkmayfoodsensitivityonelicoricespiceingredientsdamnshamewantedputcasewasntone': 17, 'agreementseveralusersbuyflavors499onlinemanufactureswebsitewouldpay8991399nothingcustomeradvisorybuysyrupsdirectsavebundleproductgreatproductspending9900machinemeansdrinklotsodaequal9900sodasfunlotlesswaste': 18, '': 19, 'impulsebuypurchasedfooditemsdecidedtrygettingamazonlaterfoundproductmuchcheaperlocalbigboxmembershipwarehousestorejerkyfreshnessfindlocalstoreshopingfresheriesofterjerky': 20, '...': 21, '...': 22, '...': 23, 'bagslotovercookedbrownpiecesalsofeltgreasykeepwipingfingersnapkin': 24, 'boughtfirstboxcupteaeverynightthoughthotflashessubsidedbitboughtanotherboxsecondboxmuchsureteabuildssystemstopsworkingteabadtastedoablepurposesagetearecommendedmanymeanscuttinghotflashesvstakingmedslinkedcancergivetrymightwork': 25, 'althoughlabeledblackbeanchipsunlikeunavailabletraderjoesversioncornchipsblackbeanthrownthatsmisleadinglabeledcornblackbeanchipsdonttastebadfarchipsgodefinitelynowhereneargoodoldtraderjoesvariety': 26, 'boughtcookiesgiftdadbirthdayunfortunately24boxesgavedadgiftmostlybrokencookiesstaletastinggreatgiftideareallypackagedhandledwellboughtdelicecookiespastproblemsrandombrokencookieboxopenedboxesyetcoursehopefindcouplebrokengivedad': 27, 'nothingmetalliccolorgoldfactyellowisntsheensparklebummed': 28, 'knownettleteaprettydistincttasteparticularbrandunbearablesmellremindedfishfoodpelletsfishytasteboughtpoundloosenettlessomewhereelselotcheapertastemuchbetter': 29, 'numerousgoogleslookingchipstersonefavoritechildhoodsnacksreportedproductclosedisagreeclosestflavorchipstersfarwouldmunchosstillconsciousdietprobablydue': 30, 'tookforevershiparrivedurableadvertizedlookingbonekeepdogsbusylikesnack': 31, '': 32, 'jamaicadrinkjbmcoffeecomedevelopefineappreciationbeanopenedmorningexpectedcleargreatlydissapointedfoundbitshuskbeandoesntmakecoffeeconsideredfillerflavorleftsomethingdesiredwelltastedlikefolgerscoffeewithoutacidhopingleavegreatreviewproducthonestyforbids': 33, 'ideareviewsbranddietersteatalkingfolloweddirectionsnothinghappenedbrewedstrongercupstillnothingevenmeasuredwater6ozletteabagseepfiveminutesnothingstrongertastingteaboxte ...

# %% [markdown]
# ## Load GloVE and build the embedding matrix to resolve overfitting gap

# %%
import numpy as np

EMBEDDING_DIM = 100  # Matches the 100d GloVe file

glove_index = {}
with open('glove.6B.100d.txt', encoding='utf-8') as f: # open the GLoVE 100d text file
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], dtype='float32')
        glove_index[word] = vector

# Build a matrix where each row = the GloVe vector for that word index
embedding_matrix = np.zeros((MAX_VOCAB, EMBEDDING_DIM))
for word, idx in tokenizer.word_index.items():
    if idx < MAX_VOCAB:
        vec = glove_index.get(word)
        if vec is not None:
            embedding_matrix[idx] = vec
# Words not found in GloVe stay as zero vectors

# %%
# The following is no longer required since we switched to the Keras Tokenizer
# Save the vocab to your folder.
# joblib.dump(vocab, "vocab.pkl")

# create an embedding layer based on the vocab created with GloVE vectors

from tensorflow.keras.layers import Embedding

Embedding(
    input_dim=MAX_VOCAB,
    output_dim=EMBEDDING_DIM,
    weights=[embedding_matrix],   # <-- your pretrained vectors
    input_length=MAX_LEN,
    trainable=False               # Freeze so it doesn't overfit
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# <Embedding name=embedding, built=True>

# %% [markdown]
# ## Transform
# The transform stage applies the data you'll use to the vocabulary created by the fit stage. You'll follow the steps below to transform the data into a form the network can understand.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences;

# Transform the training data with pad_sequences()
x_rev_train_v = pad_sequences(
    tokenizer.texts_to_sequences(x_rev_train),
    maxlen=MAX_LEN,
    padding='post',
    truncating='post'
)

# Transform the test data with pad_sequences()
x_rev_test_v = pad_sequences(
    tokenizer.texts_to_sequences(x_rev_test),
    maxlen=MAX_LEN,
    padding='post',
    truncating='post'
)

# %%
# Print out the shape of the training dataset.
print(x_rev_test_v.shape)

# Print the shape of the test dataset.
print(x_rev_train_v.shape)
# Out:
# (7200, 150)
# (16800, 150)

# %% [markdown]
# # Creating the Network
# Up to now, you've cleaned up and prepared the data and vectorized it. Now, it's time to create the network to understand the text. Now that you have the text as number inputs and three output categories, this is a machine-learning task. Thus, you can create a network that does classification to perform sentiment analysis.
#
# To get started, you'll create a model and set up the layers for the neural network.

# %% [markdown]
# ## Create the Model
# You'll use a **Sequential** model for the sentiment analysis. You'll create an input layer, several calculation layers, dropout layers, and an output layer.

# %%
# Create a sequential model.
model = Sequential()

# %% [markdown]
# ## Embedding Layer
# The first layer of the network, or input layer, will take all of the text input and start to perform calculations with it. This layer needs to be large so the network can learn about the capacity of data it will be working with. The one in this example will be set to 4000 neurons, but if you want to go larger, you can!
#
# Also, for the input layer, you'll decide on an activation algorithm. **Relu** works well for these purposes because it helps the neural network learn the complicated patterns of the dataset.

# %%
from tensorflow.keras.layers import (Embedding, Bidirectional, LSTM, Dense, Dropout, GlobalMaxPooling1D)
# Add an input layer with 6000 (up from 4000) units and an activation of 'relu'.
model.add(Embedding(MAX_VOCAB, 100, weights=[embedding_matrix], trainable=False))
model.add(Dense(units=6000, activation='relu'))

# %% [markdown]
# ## Bidirectional, MaxPooling, Dense, and Dropout Layers
# Another important aspect of this model is the dropout layers. These help prevent the network from relying too much on specific neurons and force all the neurons to perform calculations. This is important for large networks like this one! The layer is set to dropout at a rate of 0.5, which means half of the neurons.

# %%
# Add a dropout layer with a rate of 0.5.
model.add(Bidirectional(LSTM(64, dropout=0.3, recurrent_dropout=0.3, return_sequences=True)))
model.add(GlobalMaxPooling1D())
model.add(Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(Dropout(0.5))

# %% [markdown]
# ## Calculation + Output Layers
# Once you have the input, you'll add the calculation layers. This part of the network will do the bulk of the calculations. It's important to include dropout layers in this part of the network as well so that it continues to be versatile.

# %%
# Add layers to the middle of the network.
model.add(Dense(units=3, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(0.001)))

# %% [markdown]
# ## Compiling the Network
# Now that you have all the layers, you'll compile the network. First, you'll create a variable to hold the optimizer and then compile the network.
#
# The optimizer will be a general-purpose algorithm called **Adam** and the loss algorithm is **categorical cross-entropy**. Since this problem involves sorting data into categories, the metric to watch is accuracy.

# %%
# Add the compile function that calculates the loss and uses the optimizer parameter to set the optimization algorithm.
model.summary()
model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),metrics=["accuracy"])
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ ?                      │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,000,000 (3.81 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 1,000,000 (3.81 MB)

# %% [markdown]
# ## Fit Data to the Network
# Next, you'll train the network using the data that you've prepared. During this stage, you'll also decide on batch size and the number of epochs. Finally, you'll set the validation data to the test datasets you created.

# %%
# Update 5/6/2026: Both train and validation accuracy remained plateauing and awful (around 0.3276)
# after updating embeddings and adding bidirectional layers. This was with a batch size of 64,
# early stopping with patience 3, and 10 epochs.

from tensorflow.keras.callbacks import EarlyStopping

# implement EarlyStopping to prevent the validation loss from plateauing too quickly
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# Add the fit function and set the input data for this model, the epochs to the fit stage, and shuffle the data, so the network doesn't rely on a pattern to learn. (Add ReduceLROnPlateau HERE)
model.fit(
    x=x_rev_train_v,
    y=y_pol_train,
    batch_size=64,
    epochs=10,
    validation_data=(x_rev_test_v, y_pol_test)
)
# Out:
# Epoch 1/10
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 306s 1s/step - accuracy: 0.3295 - loss: 1.1116 - val_accuracy: 0.3276 - val_loss: 1.0993
# Epoch 2/10
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 314s 1s/step - accuracy: 0.3358 - loss: 1.0988 - val_accuracy: 0.3276 - val_loss: 1.0987
# Epoch 3/10
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 284s 1s/step - accuracy: 0.3344 - loss: 1.0987 - val_accuracy: 0.3276 - val_loss: 1.0987
# Epoch 4/10
# 221/263 ━━━━━━━━━━━━━━━━━━━━ 40s 975ms/step - accuracy: 0.3373 - loss: 1.0986

# %% [markdown]
# ## Evaluating the Network
# Once the network is done training, you'll get the scores from the model and print out the accuracy. This will give you a good idea of how the network performs on the test data. This network should provide an accuracy of about 0.70, which is good.

# %%
# Calculate the scores and calculate the loss and accuracy of your model.
scores = model.evaluate(x_rev_test_v, y_pol_test, verbose=1)

# Print the test accuracy of your model.
print('Test accuracy:', scores[1]) # test accuracy was only 0.4044 at last compile on 2/8/2026 (horrible)

# %% [markdown]
# ## Save the Model
# You'll add the code to export the model, so this way, you won't have to retrain it to use in the future.

# %%
# Export your model.
model.save('sentiment_analysis_v2_042.keras')
