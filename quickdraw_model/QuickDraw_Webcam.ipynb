# %% [markdown]
# # QuickDraw Webcam Runner Notebook
# This notebook contains code cells to run the webcam_drawpad.py file, which uses your webcam to recognize shapes you draw ON PAPER (*different* from the QuickDraw Drawpad model). It's used as an alternative if running the webcam_drawpad.py file directly doesn't work. Conversely, if you're having trouble running this notebook, just run the webcam_drawpad.py file directly.

# %% [markdown]
# 1. Install Pygame

# %%
# !pip install pygame opencv-python
# Out:
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
# ...
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 1.26.4
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#     Uninstalling numpy-1.26.4:
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
# ...

# %% [markdown]
# 2. Run webcam_drawpad.py in the windows terminal.

# %%
import os
import subprocess

script_path = os.path.abspath("webcam_drawpad.py")
subprocess.Popen(f'start cmd /c python "{script_path}"', shell=True)
# Out:
# <Popen: returncode: None args: 'start cmd /c python "c:\\Users\\car-m\\machi...>
